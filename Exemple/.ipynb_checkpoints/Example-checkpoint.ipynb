# %% [markdown]
# # Data analysis for CraFT output
# This toolbox is build to analyse the output from CraFT when using a 100 type law in CraFT as done during ice simulation
#
# **warning** vtk_split from CraFT compilation is used to be able to read the binairy file. It might existe a solution using directly python vtk reader to get rid of this. Need to be done ! The path to vtk_split sould be writen fully.
#
# There is something strage with vtk output. I cannot load gamma in paraview or stress, strain tensor. No data are load.
#
# ## Folder structure output

# %%
import pyCraFT.runcraft as RC

# %%
adr_C_output='data/'
time_output='09.20000000e+04'

# %%
data=RC.runcraft(adr_C_output,time_output)

# %%
basal_act=data.gamma.gamma_activity()

# %%
basal_act.plot()

# %%
data.gamma.vpstrain(data).eqVonMises().plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9d64929ba783> in <module>
# ----> 1 data.gamma.vpstrain(data).eqVonMises().plot()
#
# ~/anaconda3/lib/python3.7/site-packages/pyCraFT/gammarun.py in vpstrain(self, craft)
#      66         '''
#      67
# ---> 68         res=self.g01.vpstrain(craft)+self.g02.vpstrain(craft)+self.g03.vpstrain(craft)+self.g04.vpstrain(craft)+self.g05.vpstrain(craft)+self.g06.vpstrain(craft)+self.g07.vpstrain(craft)+self.g08.vpstrain(craft)+self.g09.vpstrain(craft)+self.g10.vpstrain(craft)+self.g11.vpstrain(craft)+self.g12.vpstrain(craft)
#      69
#      70         return res
#
# ~/anaconda3/lib/python3.7/site-packages/pyCraFT/gammamap.py in vpstrain(self, craft)
#     135         :rtype: sTM.symetricTensorMap
#     136         '''
# --> 137         return self.schmidtensor(craft,use_sTM=True)*self.map
#     138
# ...

# %%
# %matplotlib qt
data.gamma.Lp().extract_data()

# %%
data.strain.eqVonMises().plot()

# %%
import matplotlib.pyplot as plt
plt.plot(data.strain.eqVonMises().field.flatten(),data.gamma.vpstrain().eqVonMises().field.flatten(),'+')

# %%
data.grainId.plot()

# %%
st=data.gamma.g01.schmidtensor()

# %%
st

# %%
def matrot(phi1,phi,phi2):
    Rphi1=np.matrix([[np.cos(phi1), -np.sin(phi1), 0],[np.sin(phi1), np.cos(phi1), 0],[0,0,1]])
    Rphi=np.matrix([[1,0,0],[0,np.cos(phi), -np.sin(phi)],[0,np.sin(phi), np.cos(phi)]])
    Rphi2=np.matrix([[np.cos(phi2), -np.sin(phi2), 0],[np.sin(phi2), np.cos(phi2), 0],[0,0,1]])
    
    return Rphi2*Rphi*Rphi1

# %%
import numpy as np
phi1=1
Rphi1=np.matrix([[np.cos(phi1), -np.sin(phi1), 0],[np.sin(phi1), np.cos(phi1), 0],[0,0,1]])

# %%
np.transpose(matrot(np.pi/4,np.pi/6,np.pi/7))*st*matrot(np.pi/4,np.pi/6,np.pi/7)

# %%
matrot(np.pi/4,np.pi/6,np.pi/7)*st*np.transpose(matrot(np.pi/4,np.pi/6,np.pi/7))

# %%
data.grainId.field[100,0]

# %%
np.where(data.orientation[:,0]==data.grainId.field[1,0])[0][0]

# %%
data.orientation[:,0]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ss=np.shape(data.grainId.field)

t11=np.zeros(ss)
t12=np.zeros(ss)
t13=np.zeros(ss)
t22=np.zeros(ss)
t23=np.zeros(ss)
t33=np.zeros(ss)

for i in list(range(len(data.orientation))):
    idx,idy=np.where(data.orientation[i,0]==data.grainId.field)

# %%
i=0
ss=np.shape(data.grainId.field)
t11=np.zeros(ss)
idx,idy=np.where(data.orientation[i,0]==data.grainId.field)

# %%
idx
# Out:
# array([ 0,  0,  0, ..., 97, 97, 97])

# %%
idy
# Out:
# array([ 0,  1,  2, ..., 14, 15, 16])

# %%
t11[idx,idy]=1

# %%
plt.imshow(t11)
plt.axis('equal')
# Out:
# (-0.5, 494.5, 538.5, -0.5)
